# %% [markdown]
# # 13. Reading Files in Python
#
#  * __To Read a text files in Python follow these steps:__
#  * __First, Open a text file for reading by using the open() function.__
#  * __Second, read text from the text file using the file read(), readline(), or readlines() method of the file object.__
#  * __Third, close the file using the close() method. This frees up resources and ensures consistency across different python versions.__
#
#  * __Method---------------------Description__
#  * __writeable()---------------> Returns whether the files can be written or not.__
#  * __readable()----------------> Returns whether the files stream can be read or not.__
#  * __read()--------------------> Returns the file content.__
#  * __readline()----------------> Returns one line from the file.__
#  * __readlines()---------------> Returns a list of lines from the file.__
#  * __write()-------------------> Writes the specified string to the file.__
#  * __writelines()--------------> Writes a list of strings to the file.__
#  * __close()-------------------> Closed the file.__
#  * __flush()-------------------> Flushed the internal buffer.__
#  * __seek()--------------------> Change the file position.__
#  * __tell()--------------------> Returns the current file.__
#  * __truncate()----------------> Resize the file to a specified.__

# %%
file_name="amitabh_bacchan.txt"
#file=open(file_name,'r')
file = open(file_name, errors="ignore")
content=file.read()
content
# Out:
# 'Amitabh Bachchan (pronounced [É™mÉªËˆtÌªÉ‘ËbÊ± ËˆbÉ™tËÊƒÉ™n]; born as Amitabh Srivastava;[1] 11 October 1942[9]) is an Indian actor, film producer, television host, occasional playback singer, and former politician actively engaged in Hindi cinema. With a cinematic journey spanning over five decades, he has played pivotal roles in over 200 films. Widely recognised as one of the most accomplished and influential actors in the history of Indian cinema.[10] Bachchan is often hailed as the Shahenshah of Bollywood, Sadi Ke Mahanayak (translated as "Greatest actor of the century" in Hindi), Star of the Millennium, or simply Big B.[11] His dominance in the Indian film industry during the 1970sâ€“80s led the French director FranÃ§ois Truffaut to describe it as a "one-man industry". [12]\n\nBachchan was born in 1942 in Allahabad (now Prayagraj) to the Hindi poet Harivansh Rai Bachchan and his wife, the social activist Teji Bachchan. He was educated at Sherwood College, Nainital, and Kirori M
# ...

# %%
print(content)
# Out:
# Amitabh Bachchan (pronounced [É™mÉªËˆtÌªÉ‘ËbÊ± ËˆbÉ™tËÊƒÉ™n]; born as Amitabh Srivastava;[1] 11 October 1942[9]) is an Indian actor, film producer, television host, occasional playback singer, and former politician actively engaged in Hindi cinema. With a cinematic journey spanning over five decades, he has played pivotal roles in over 200 films. Widely recognised as one of the most accomplished and influential actors in the history of Indian cinema.[10] Bachchan is often hailed as the Shahenshah of Bollywood, Sadi Ke Mahanayak (translated as "Greatest actor of the century" in Hindi), Star of the Millennium, or simply Big B.[11] His dominance in the Indian film industry during the 1970sâ€“80s led the French director FranÃ§ois Truffaut to describe it as a "one-man industry". [12]
#
# ...

# %%
content
# Out:
# 'Amitabh Bachchan (pronounced [É™mÉªËˆtÌªÉ‘ËbÊ± ËˆbÉ™tËÊƒÉ™n]; born as Amitabh Srivastava;[1] 11 October 1942[9]) is an Indian actor, film producer, television host, occasional playback singer, and former politician actively engaged in Hindi cinema. With a cinematic journey spanning over five decades, he has played pivotal roles in over 200 films. Widely recognised as one of the most accomplished and influential actors in the history of Indian cinema.[10] Bachchan is often hailed as the Shahenshah of Bollywood, Sadi Ke Mahanayak (translated as "Greatest actor of the century" in Hindi), Star of the Millennium, or simply Big B.[11] His dominance in the Indian film industry during the 1970sâ€“80s led the French director FranÃ§ois Truffaut to describe it as a "one-man industry". [12]\n\nBachchan was born in 1942 in Allahabad (now Prayagraj) to the Hindi poet Harivansh Rai Bachchan and his wife, the social activist Teji Bachchan. He was educated at Sherwood College, Nainital, and Kirori M
# ...

# %%
# Printing the file path

print(file.name)

# Priting the mode of file
print(file.mode)

# priting the type of file
print(type(content))
# Out:
# amitabh_bacchan.txt
# r
# <class 'str'>

# %%
# Verification of the file

file.closed
# Out:
# False

# %%
# closing the file.
file.close()

# %%
file.closed
# Out:
# True

# %%
content
# Out:
# 'Amitabh Bachchan (pronounced [É™mÉªËˆtÌªÉ‘ËbÊ± ËˆbÉ™tËÊƒÉ™n]; born as Amitabh Srivastava;[1] 11 October 1942[9]) is an Indian actor, film producer, television host, occasional playback singer, and former politician actively engaged in Hindi cinema. With a cinematic journey spanning over five decades, he has played pivotal roles in over 200 films. Widely recognised as one of the most accomplished and influential actors in the history of Indian cinema.[10] Bachchan is often hailed as the Shahenshah of Bollywood, Sadi Ke Mahanayak (translated as "Greatest actor of the century" in Hindi), Star of the Millennium, or simply Big B.[11] His dominance in the Indian film industry during the 1970sâ€“80s led the French director FranÃ§ois Truffaut to describe it as a "one-man industry". [12]\n\nBachchan was born in 1942 in Allahabad (now Prayagraj) to the Hindi poet Harivansh Rai Bachchan and his wife, the social activist Teji Bachchan. He was educated at Sherwood College, Nainital, and Kirori M
# ...

# %%
fname="amitabh_bacchan.txt"
with open(fname,'r',errors="ignore") as f:
    content1=f.read()
    print(content1)
# Out:
# Amitabh Bachchan (pronounced [É™mÉªËˆtÌªÉ‘ËbÊ± ËˆbÉ™tËÊƒÉ™n]; born as Amitabh Srivastava;[1] 11 October 1942[9]) is an Indian actor, film producer, television host, occasional playback singer, and former politician actively engaged in Hindi cinema. With a cinematic journey spanning over five decades, he has played pivotal roles in over 200 films. Widely recognised as one of the most accomplished and influential actors in the history of Indian cinema.[10] Bachchan is often hailed as the Shahenshah of Bollywood, Sadi Ke Mahanayak (translated as "Greatest actor of the century" in Hindi), Star of the Millennium, or simply Big B.[11] His dominance in the Indian film industry during the 1970sâ€“80s led the French director FranÃ§ois Truffaut to describe it as a "one-man industry". [12]
#
# ...

# %%
# Reading certain amount of characters in the file.

with open(fname,'r',errors='ignore') as f:
    print(f.read(100))
    print(f.read(50))
    print(f.read(1000))
# Out:
# Amitabh Bachchan (pronounced [É™mÉªËˆtÌªÉ‘ËbÊ± ËˆbÉ™tËÊƒÉ™n]; born as Amitabh Srivastava;[1] 11 Octo
# ber 1942[9]) is an Indian actor, film producer, te
# levision host, occasional playback singer, and former politician actively engaged in Hindi cinema. With a cinematic journey spanning over five decades, he has played pivotal roles in over 200 films. Widely recognised as one of the most accomplished and influential actors in the history of Indian cinema.[10] Bachchan is often hailed as the Shahenshah of Bollywood, Sadi Ke Mahanayak (translated as "Greatest actor of the century" in Hindi), Star of the Millennium, or simply Big B.[11] His dominance in the Indian film industry during the 1970sâ€“80s led the French director FranÃ§ois Truffaut to describe it as a "one-man industry". [12]
#
# ...

# %%
# readline

with open(fname,'r',errors='ignore') as f:
    print("The first line of the text is: ",f.readline())
    print("The second line of the text is:",f.readline())
    print("The Third Paragraph of the text is:",f.readline())
# Out:
# The first line of the text is:  Amitabh Bachchan (pronounced [É™mÉªËˆtÌªÉ‘ËbÊ± ËˆbÉ™tËÊƒÉ™n]; born as Amitabh Srivastava;[1] 11 October 1942[9]) is an Indian actor, film producer, television host, occasional playback singer, and former politician actively engaged in Hindi cinema. With a cinematic journey spanning over five decades, he has played pivotal roles in over 200 films. Widely recognised as one of the most accomplished and influential actors in the history of Indian cinema.[10] Bachchan is often hailed as the Shahenshah of Bollywood, Sadi Ke Mahanayak (translated as "Greatest actor of the century" in Hindi), Star of the Millennium, or simply Big B.[11] His dominance in the Indian film industry during the 1970sâ€“80s led the French director FranÃ§ois Truffaut to describe it as a "one-man industry". [12]
#
# The second line of the text is:
#
# ...

# %%
# file open with loop
with open(fname,'r',errors='ignore') as f:
    line_number=1
    for i in f:
        print("Paragraph:",str(line_number) ,':',i)
        line_number+=1
# Out:
# Paragraph: 1 : Amitabh Bachchan (pronounced [É™mÉªËˆtÌªÉ‘ËbÊ± ËˆbÉ™tËÊƒÉ™n]; born as Amitabh Srivastava;[1] 11 October 1942[9]) is an Indian actor, film producer, television host, occasional playback singer, and former politician actively engaged in Hindi cinema. With a cinematic journey spanning over five decades, he has played pivotal roles in over 200 films. Widely recognised as one of the most accomplished and influential actors in the history of Indian cinema.[10] Bachchan is often hailed as the Shahenshah of Bollywood, Sadi Ke Mahanayak (translated as "Greatest actor of the century" in Hindi), Star of the Millennium, or simply Big B.[11] His dominance in the Indian film industry during the 1970sâ€“80s led the French director FranÃ§ois Truffaut to describe it as a "one-man industry". [12]
#
# Paragraph: 2 :
#
# ...

# %%
# file open with function()

# def and return,print()

def file(x):
    file_name=x
    file=open(file_name,'r',errors="ignore")
    content2=file.read()
    print(content)
file('amitabh_bacchan.txt')
# Out:
# Amitabh Bachchan (pronounced [É™mÉªËˆtÌªÉ‘ËbÊ± ËˆbÉ™tËÊƒÉ™n]; born as Amitabh Srivastava;[1] 11 October 1942[9]) is an Indian actor, film producer, television host, occasional playback singer, and former politician actively engaged in Hindi cinema. With a cinematic journey spanning over five decades, he has played pivotal roles in over 200 films. Widely recognised as one of the most accomplished and influential actors in the history of Indian cinema.[10] Bachchan is often hailed as the Shahenshah of Bollywood, Sadi Ke Mahanayak (translated as "Greatest actor of the century" in Hindi), Star of the Millennium, or simply Big B.[11] His dominance in the Indian film industry during the 1970sâ€“80s led the French director FranÃ§ois Truffaut to describe it as a "one-man industry". [12]
#
# ...

# %%
# file open with class and object
class file:
    def __init__(self,filename):
        self.filename=filename
    def openfile(self):
        file_name=self.filename
        file=open(file_name,'r',errors='ignore')
        x1=file.read()
        return x1
def main():
    file1=file("amitabh_bacchan.txt")
    print(file1.openfile())
main()
# Out:
# Amitabh Bachchan (pronounced [É™mÉªËˆtÌªÉ‘ËbÊ± ËˆbÉ™tËÊƒÉ™n]; born as Amitabh Srivastava;[1] 11 October 1942[9]) is an Indian actor, film producer, television host, occasional playback singer, and former politician actively engaged in Hindi cinema. With a cinematic journey spanning over five decades, he has played pivotal roles in over 200 films. Widely recognised as one of the most accomplished and influential actors in the history of Indian cinema.[10] Bachchan is often hailed as the Shahenshah of Bollywood, Sadi Ke Mahanayak (translated as "Greatest actor of the century" in Hindi), Star of the Millennium, or simply Big B.[11] His dominance in the Indian film industry during the 1970sâ€“80s led the French director FranÃ§ois Truffaut to describe it as a "one-man industry". [12]
#
# ...

# %%
class files():
    def __init__(self,name2):
        self.name2=name2
    def openfile(self):
        with open(self.name2,'r',errors="ignore") as f:
            content2=f.read()
            print (content2)

name3="amitabh_bacchan.txt"
x2=files(name3)
x2.openfile()
# Out:
# Amitabh Bachchan (pronounced [É™mÉªËˆtÌªÉ‘ËbÊ± ËˆbÉ™tËÊƒÉ™n]; born as Amitabh Srivastava;[1] 11 October 1942[9]) is an Indian actor, film producer, television host, occasional playback singer, and former politician actively engaged in Hindi cinema. With a cinematic journey spanning over five decades, he has played pivotal roles in over 200 films. Widely recognised as one of the most accomplished and influential actors in the history of Indian cinema.[10] Bachchan is often hailed as the Shahenshah of Bollywood, Sadi Ke Mahanayak (translated as "Greatest actor of the century" in Hindi), Star of the Millennium, or simply Big B.[11] His dominance in the Indian film industry during the 1970sâ€“80s led the French director FranÃ§ois Truffaut to describe it as a "one-man industry". [12]
#
# ...

# %%
# file open with exception handling

try:
    file_name='amitabh_bacchan.txt'
    file=open(file_name,'r',errors='ignore')
    content4=file.read()
    print(content4)
except FileNotFoundError:
    print("File Not Found")
# Out:
# Amitabh Bachchan (pronounced [É™mÉªËˆtÌªÉ‘ËbÊ± ËˆbÉ™tËÊƒÉ™n]; born as Amitabh Srivastava;[1] 11 October 1942[9]) is an Indian actor, film producer, television host, occasional playback singer, and former politician actively engaged in Hindi cinema. With a cinematic journey spanning over five decades, he has played pivotal roles in over 200 films. Widely recognised as one of the most accomplished and influential actors in the history of Indian cinema.[10] Bachchan is often hailed as the Shahenshah of Bollywood, Sadi Ke Mahanayak (translated as "Greatest actor of the century" in Hindi), Star of the Millennium, or simply Big B.[11] His dominance in the Indian film industry during the 1970sâ€“80s led the French director FranÃ§ois Truffaut to describe it as a "one-man industry". [12]
#
# ...

# %%
len(content4)
# Out:
# 26213

# %%
with open(fname,'r',errors="ignore") as f:
    str=''
    for line in f:
        str+=line
    print(f"Total Characters of the text is: {len(str)}")
    print('Total Characters of the text without spaces is:',len(str.replace(' ','')))
# Out:
# Total Characters of the text is: 26213
# Total Characters of the text without spaces is: 22019
