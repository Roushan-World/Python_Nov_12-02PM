# %%
# Reading the text file

x1="amitabh_bacchan.txt"
y=open(x1,'r',errors="ignore")
read=y.read()
read
# Out:
# 'Amitabh Bachchan (pronounced [É™mÉªËˆtÌªÉ‘ËbÊ± ËˆbÉ™tËÊƒÉ™n]; born as Amitabh Srivastava;[1] 11 October 1942[9]) is an Indian actor, film producer, television host, occasional playback singer, and former politician actively engaged in Hindi cinema. With a cinematic journey spanning over five decades, he has played pivotal roles in over 200 films. Widely recognised as one of the most accomplished and influential actors in the history of Indian cinema.[10] Bachchan is often hailed as the Shahenshah of Bollywood, Sadi Ke Mahanayak (translated as "Greatest actor of the century" in Hindi), Star of the Millennium, or simply Big B.[11] His dominance in the Indian film industry during the 1970sâ€“80s led the French director FranÃ§ois Truffaut to describe it as a "one-man industry". [12]\n\nBachchan was born in 1942 in Allahabad (now Prayagraj) to the Hindi poet Harivansh Rai Bachchan and his wife, the social activist Teji Bachchan. He was educated at Sherwood College, Nainital, and Kirori M
# ...

# %%
print(read)
# Out:
# Amitabh Bachchan (pronounced [É™mÉªËˆtÌªÉ‘ËbÊ± ËˆbÉ™tËÊƒÉ™n]; born as Amitabh Srivastava;[1] 11 October 1942[9]) is an Indian actor, film producer, television host, occasional playback singer, and former politician actively engaged in Hindi cinema. With a cinematic journey spanning over five decades, he has played pivotal roles in over 200 films. Widely recognised as one of the most accomplished and influential actors in the history of Indian cinema.[10] Bachchan is often hailed as the Shahenshah of Bollywood, Sadi Ke Mahanayak (translated as "Greatest actor of the century" in Hindi), Star of the Millennium, or simply Big B.[11] His dominance in the Indian film industry during the 1970sâ€“80s led the French director FranÃ§ois Truffaut to describe it as a "one-man industry". [12]
#
# ...

# %%
#pip install PyPDF2


import PyPDF2

# %%
def open_pdf(file_path):
    # Open the PDF file in binary mode
    with open(file_path, 'rb') as file:
        # Create a PDF reader object
        pdf_reader = PyPDF2.PdfReader(file)

        # Get the number of pages in the PDF
        num_pages = pdf_reader.numPages
        print(f'Total number of pages: {num_pages}')

        # Read each page
        for page_num in range(num_pages):
            # Extract text from the page
            page = pdf_reader.getPage(page_num)
            text = page.extractText()

            # Print the text from the current page
            print(f'Page {page_num + 1}:\n{text}')

# Replace 'your_file.pdf' with the path to your PDF file
open_pdf('your_file.pdf')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 21
#      18             print(f'Page {page_num + 1}:\n{text}')
#      20 # Replace 'your_file.pdf' with the path to your PDF file
# ---> 21 open_pdf('your_file.pdf')
#
# Cell In[9], line 3, in open_pdf(file_path)
#       1 def open_pdf(file_path):
#       2     # Open the PDF file in binary mode
# ----> 3     with open(file_path, 'rb') as file:
#       4         # Create a PDF reader object
#       5         pdf_reader = PyPDF2.PdfReader(file)
#       7         # Get the number of pages in the PDF
#
# File C:\Python311\Lib\site-packages\IPython\core\interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
# ...

# %%
# print the file path

# %%
import pandas as pd

# %%
x=pd.read_csv("C:\\Users\\Admin\\Downloads\\Final_Employees_Data.csv")
x
# Out:
#       Eid                Ename  Experience  Total_projects    Rating  \
# 0       1            Dana Bond           2               2  1.000000
# 1       2        Jesus Hampton           9              13  1.444444
# 2       3         Teresa Munoz          15              16  1.066667
# 3       4     Annette Dipietro          18              19  1.055556
# 4       5     Jennifer Fortner          22              15  0.681818
# ..    ...                  ...         ...             ...       ...
# 995   996         Nicole Meeks          24              27  1.125000
# 996   997         Trista Cheek           3               6  2.000000
# 997   998     Constance Rozier          14               5  0.357143
# 998   999  Elizabeth Bannister          11               9  0.818182
# 999  1000          Susan Weber          11              13  1.181818
#
#     Area_of_Interest_1 Area_of_Interest_2 Area_of_Interest_3 Language1  \
# ...

# %%
x.head(51)
# Out:
#     Eid                Ename  Experience  Total_projects    Rating  \
# 0     1            Dana Bond           2               2  1.000000
# 1     2        Jesus Hampton           9              13  1.444444
# 2     3         Teresa Munoz          15              16  1.066667
# 3     4     Annette Dipietro          18              19  1.055556
# 4     5     Jennifer Fortner          22              15  0.681818
# 5     6            Mary Todd           7              13  1.857143
# 6     7      Nicolas Fulcher           2               2  1.000000
# 7     8     Bernice Bousquet           3               4  1.333333
# 8     9       William Berger           2               5  2.500000
# 9    10     Kennith Hamilton           3               8  2.666667
# 10   11    Shannon Berryhill           7              17  2.428571
# 11   12         Rachel Morse           3               6  2.000000
# 12   13        Robert Wilson          11               8  0.727273
# ...

# %%
x.tail(20)
# Out:
#       Eid                Ename  Experience  Total_projects    Rating  \
# 980   981      Peter Dellinger           6               5  0.833333
# 981   982        Cynthia Anaya          19              29  1.526316
# 982   983       Sylvia Thigpen           2               3  1.500000
# 983   984         John Gerrald           4               5  1.250000
# 984   985            Jose Bond          17              29  1.705882
# 985   986      Russell Collyer           8              16  2.000000
# 986   987       William Nelson          15               8  0.533333
# 987   988        Thomas Barton          22              21  0.954545
# 988   989         Angelo Houck          23              29  1.260870
# 989   990           Ricky Hood          20              16  0.800000
# 990   991        Joan Takemura           5               7  1.400000
# 991   992      Stephen Burritt          19              19  1.000000
# 992   993       Virginia Hamby          13              12  0.923077
# ...

# %%
print(y.name)

print(y.mode)

print(type(read))
# Out:
# amitabh_bacchan.txt
# r
# <class 'str'>

# %%
added_text=["My name is Rupali Gurav.\t\t",
           "My name is Adnan Sheikh."]

fname='rupali.txt'

with open(fname,'w') as f:
    for i in added_text:
        print(i)
        f.write(i)
# Out:
# My name is Rupali Gurav.
# My name is Adnan Sheikh.

# %%
i=1
print("Numbers\t\tSquares")
while(i<=10):
    print(i,"\t:", i**2)
    i+=1
# Out:
# Numbers		Squares
# 1 	: 1
# 2 	: 4
# 3 	: 9
# 4 	: 16
# 5 	: 25
# 6 	: 36
# 7 	: 49
# 8 	: 64
# 9 	: 81
# 10 	: 100

# %%
fname='rupali.txt'

with open(fname,'w') as x:
    x.write('My name is Rupali Gurav.')

# %%
try:
    def write(x,y):
        with open(x,'w') as f:
            for i in range(y):
                s=input("Enter any text")
                f.write(s)
                f.write("\n")
    x=input('Enter text file name:')
    x=x+'.docx'
    y=int(input("Enter Number of lines:"))
    write(x,y)
except ValueError:
    print("Pass the correct Integer value")
print("File are Written.")
# Out:
# Enter text file name: rupali
# Enter Number of lines: 2
# Enter any text My name is rupali
# Enter any text my name is adnan
# File are Written.
